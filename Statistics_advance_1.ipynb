# %% [markdown]
# Theory questions

# %% [markdown]
# 1.What is a random variable in probability theory?
# - In probability theory, a random variable is a variable whose value is a numerical outcome of a random phenomenon. It's a function that assigns a numerical value to each possible outcome of a random experiment. Think of it as a way to quantify the results of a random event.
#
# 2.What are the types of random variables?
# - There are two main types of random variables: discrete and continuous. Discrete random variables can only take on a finite number of values or a countably infinite number of values, often integers. Continuous random variables, on the other hand, can take on any value within a given range or interval.
#
# 3.What is the difference between discrete and continuous distributions?
# - The main difference between discrete and continuous distributions lies in the nature of the variable they describe. Discrete distributions deal with countable, separate values, while continuous distributions deal with variables that can take on any value within a given range.
#
# 4.What are probability distribution functions (PDF)?
# - A Probability Density Function (PDF) describes the likelihood of a continuous random variable falling within a specific range of values. It's a function that represents the density of probability rather than directly giving probabilities.
#
# 5.How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# - The Probability Density Function (PDF) and Cumulative Distribution Function (CDF) are both functions used to describe the distribution of a random variable, but they represent different aspects. The PDF gives the probability density at a specific point, while the CDF gives the probability that a random variable is less than or equal to a specific value.
#
# 6.What is a discrete uniform distribution?
# - A discrete uniform distribution is a probability distribution where a finite number of outcomes are all equally likely to occur. It's a simple distribution where each possible value within a defined range has the same probability of being selected.
#
# 7.What are the key properties of a Bernoulli distribution?
# - A Bernoulli distribution models a random event with two possible outcomes, typically labeled as success (1) and failure (0), with a fixed probability of success p. Key properties include its discrete nature (only two possible values), a single parameter p determining success probability, independent trials, and a mean of p and variance of p(1-p).
#
# 8.What is the binomial distribution, and how is it used in probability?
# - The binomial distribution is a probability distribution that models the probability of obtaining a specific number of successes in a fixed number of independent trials, where each trial has only two possible outcomes (success or failure) and the probability of success is constant across all trials. It's used in probability to analyze situations with binary outcomes, like coin flips, defect rates, or survey responses.
#
# 9.What is the Poisson distribution and where is it applied?
# - The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space if these events occur with a known constant mean rate and independently of the time since the last event. It's used to model the probability of a certain number of successes (events) occurring within a fixed interval, given the average rate of occurrence.
#
# 10.What is a continuous uniform distribution?
# - A continuous uniform distribution is a probability distribution where a continuous random variable is equally likely to take any value within a specified range (a, b). This means the probability of the variable falling within any sub-interval of the same width is the same.
#
# 11.What are the characteristics of a normal distribution?
# - A normal distribution, often called a bell curve, is characterized by its symmetry, bell shape, and the equality of its mean, median, and mode. It's defined by two parameters: the mean (which indicates the center) and the standard deviation (which indicates the spread or dispersion of the data).
#
# 12.What is the standard normal distribution, and why is it important?
# - The standard normal distribution is a specific type of normal distribution with a mean of 0 and a standard deviation of 1. It's a crucial concept in statistics because it allows for the comparison of data from different normal distributions and enables probability calculations using z-scores. By converting data into z-scores (number of standard deviations from the mean), you can use a standard normal table to find probabilities associated with specific values.
#
# 13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem (CLT) states that the distribution of sample means will approximate a normal distribution, regardless of the original population's distribution, as the sample size becomes sufficiently large. This is crucial because it allows statisticians to apply statistical methods designed for normal distributions to a wide range of problems, even when the underlying data isn't normally distributed.
#
# 14.How does the Central Limit Theorem relate to the normal distribution?
# - The central limit theorem (CLT) essentially states that the distribution of sample means will approximate a normal distribution, regardless of the underlying population distribution, as long as the sample size is sufficiently large. This means that even if you are sampling from a population that is not normally distributed, the averages of multiple samples will tend towards a normal distribution.
#
# 15.What is the application of Z statistics in hypothesis testing?
# - Z-statistics, calculated using a z-test, are applied in hypothesis testing to determine if there's a significant difference between a sample mean and a population mean, or between the means of two samples, when certain conditions are met. Specifically, z-tests are used when the population variance is known, or when the sample size is large (typically n ≥ 30). The z-statistic helps assess the likelihood of observing the sample data if the null hypothesis is true.
#
# 16.How do you calculate a Z-score, and what does it represent?
# - A z-score, also known as a standard score, indicates how many standard deviations a data point is away from the mean of a distribution. It's calculated by subtracting the mean from a data point and then dividing the result by the standard deviation. A positive z-score means the data point is above the mean, while a negative z-score means it's below the mean.
#
# 17.What are point estimates and interval estimates in statistics?
# - In statistics, point estimates and interval estimates are two methods used to estimate unknown population parameters from sample data. Point estimates provide a single value as the best guess for the parameter, while interval estimates provide a range of values that are likely to contain the parameter, along with a level of confidence.
#
# 18.What is the significance of confidence intervals in statistical analysis?
# - Confidence intervals in statistical analysis are crucial because they provide a range of plausible values for an unknown population parameter, offering a more informative measure of uncertainty than a single point estimate. They help researchers understand the reliability and precision of their estimates, guiding them in making data-driven decisions.
#
# 19.What is the relationship between a Z-score and a confidence interval?
# - A Z-score, which indicates how many standard deviations a data point is from the mean, is directly related to a confidence interval, which provides a range of plausible values for a population parameter. The Z-score helps determine the margin of error used in calculating the confidence interval. A higher Z-score, indicating a greater distance from the mean, results in a wider confidence interval, reflecting a higher level of uncertainty.
#
# 20.How are Z-scores used to compare different distributions?
# - Z-scores are used to compare data from different distributions by standardizing the values. They represent how many standard deviations a data point is from its distribution's mean, allowing for direct comparison even if the distributions have different means and standard deviations.
#
# 21.What are the assumptions for applying the Central Limit Theorem?
# - The Central Limit Theorem (CLT) requires a few key assumptions to be met for the sampling distribution of sample means to approximate a normal distribution. These include: random sampling, independence of samples, a sufficiently large sample size, and sometimes, that the sample size is less than 10% of the population when sampling without replacement.
#
# 22.What is the concept of expected value in a probability distribution?
# - The expected value in a probability distribution represents the long-run average outcome of a random variable. It's a weighted average of all possible values, where each value is weighted by its corresponding probability. Essentially, it tells you what you can "expect" to happen on average if you repeat an experiment many times.
#
# 23.How does a probability distribution relate to the expected outcome of a random variable?
# - A probability distribution defines the likelihood of each possible outcome of a random variable, and the expected value is a way to summarize this distribution into a single, representative number. Specifically, the expected value represents the average outcome you would expect if you repeated the random experiment many times.

# %% [markdown]
# Practical questions

# %% [markdown]
# 1.Write a Python program to generate a random variable and display its value.

# %%
import random

random_variable = random.randint(1, 100)

print("Random variable value:", random_variable)
# Out:
# Random variable value: 47

# %% [markdown]
# 2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import matplotlib.pyplot as plt

# Possible outcomes of a fair dice (1 to 6)
values = [1, 2, 3, 4, 5, 6]

# All outcomes have equal probability in a discrete uniform distribution
probabilities = [1/6] * 6

# Plotting the PMF
plt.bar(values, probabilities)
plt.title("PMF of a Fair Dice Roll")
plt.xlabel("Dice Value")
plt.ylabel("Probability")
plt.ylim(0, 0.2)  # Set Y-axis limit for better view
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# 3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    if x not in [0, 1]:
        return 0
    return p if x == 1 else 1 - p

# Let's say the coin has a 70% chance of getting heads (1) and 30% for tails (0)
p_heads = 0.7

# Calculate and print probabilities
print("Probability of getting Tails (0):", bernoulli_pdf(0, p_heads))
print("Probability of getting Heads (1):", bernoulli_pdf(1, p_heads))
# Out:
# Probability of getting Tails (0): 0.30000000000000004
# Probability of getting Heads (1): 0.7

# %% [markdown]
# x = 0 means tails
#
# x = 1 means heads
#
# p = 0.7 means heads has a 70% chance

# %% [markdown]
# 4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10      # number of trials
p = 0.5     # probability of success
size = 1000 # number of samples to generate

# Generate binomial samples
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=np.arange(n+2)-0.5, edgecolor='black', density=True)
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(n+1))
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# 5.Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.poisson(lam=3, size=100)

# Plot histogram
plt.hist(data, bins=range(0, max(data)+2), edgecolor='black', align='left')
plt.title("Poisson Distribution (λ = 3)")
plt.xlabel("Number of Events")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete uniform distribution: outcomes from 1 to 6 (like a fair dice)
values = np.arange(1, 7)             # [1, 2, 3, 4, 5, 6]
probability = 1 / len(values)        # equal probability for each

# CDF calculation
cdf = np.cumsum([probability] * len(values))

# Plotting the CDF
plt.step(values, cdf, where='post', label='CDF', color='blue')
plt.scatter(values, cdf, color='red')
plt.title("CDF of Discrete Uniform Distribution (Dice Roll)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.ylim(0, 1.1)
plt.grid(True)
plt.show()

# %% [markdown]
# 7.Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 1000 samples from a continuous uniform distribution between 0 and 1
data = np.random.uniform(low=0.0, high=1.0, size=1000)

# Plot histogram
plt.hist(data, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution (0 to 1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 8.Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate 1000 data points from a normal distribution with mean=0 and std=1
data = np.random.normal(loc=0, scale=1, size=1000)

# Plot histogram
plt.hist(data, bins=30, edgecolor='black', density=True)
plt.title("Histogram of Normal Distribution (mean=0, std=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 9.Write a Python function to calculate Z-scores from a dataset and plot them

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array([5, 7, 9, 10, 6])

# Calculate Z-scores
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# Print Z-scores
print("Z-scores:", z_scores)

# Plot Z-scores
plt.plot(z_scores, marker='o')
plt.title("Z-scores")
plt.xlabel("Index")
plt.ylabel("Z-score")
plt.axhline(0, color='gray', linestyle='--')  # line at mean
plt.grid(True)
plt.show()
# Out:
# Z-scores: [-1.29399328 -0.21566555  0.86266219  1.40182605 -0.75482941]

# %% [markdown]
# 10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

 # Define non-normal population (Exponential distribution)
population = np.random.exponential(scale=2.0, size=100000)

# CLT setup
sample_size = 50        # number of observations per sample
num_samples = 1000       # number of samples to draw
sample_means = []

# Draw samples and calculate their means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Plot histogram of sample means
plt.hist(sample_means, bins=50, density=True, edgecolor='black')
plt.title("CLT: Distribution of Sample Means (n=50)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 15.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Population parameters
mu = 50      # Mean of population
sigma = 10   # Std deviation
population_size = 100000

# Generate normal population data
population = np.random.normal(mu, sigma, population_size)

# CLT simulation setup
sample_size = 30
num_samples = 1000
sample_means = []

# Draw multiple samples and store means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))

# Plot histogram of sample means
plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title(f"CLT with Normal Distribution (n={sample_size}, samples={num_samples})")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %% [markdown]
# 16.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    # Generate values from -4 to 4 (covers ~99.99% of standard normal)
    x = np.linspace(-4, 4, 1000)

    # Calculate the PDF of standard normal distribution
    y = norm.pdf(x, loc=0, scale=1)

    # Plot
    plt.plot(x, y, label='Standard Normal PDF', color='blue')
    plt.title("Standard Normal Distribution (mean=0, std=1)")
    plt.xlabel("x")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal()

# %% [markdown]
# 17.Generate random variables and calculate their corresponding probabilities using the binomial distribution

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters
n = 15      # number of trials
p = 0.5      # probability of success
size = 1000  # number of random variables to generate

# Generate random binomial variables
samples = np.random.binomial(n=n, p=p, size=size)

# Calculate probabilities (PMF) for each possible outcome
x = np.arange(0, n+1)                # possible outcomes: 0 to n
pmf = binom.pmf(x, n, p)             # probability mass function

# Plot the PMF
plt.bar(x, pmf, color='skyblue', edgecolor='black')
plt.title("Binomial Distribution PMF (n=15, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# 18.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Input: data point, mean, and standard deviation
data_point = 85
mean = 70
std_dev = 10

# Step 1: Calculate Z-score
z_score = (data_point - mean) / std_dev
print(f"Z-score for {data_point} is: {z_score:.2f}")

# Step 2: Plot standard normal distribution
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.plot(x, y, label='Standard Normal PDF', color='blue')
plt.fill_between(x, y, where=(x < z_score), color='lightblue', alpha=0.5, label='Area left of Z')
plt.axvline(z_score, color='red', linestyle='--', label=f'Z = {z_score:.2f}')
plt.title("Standard Normal Distribution with Z-score")
plt.xlabel("Z-value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score for 85 is: 1.50

# %% [markdown]
# 19.Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
from scipy.stats import norm

# Step 1: Given values
population_mean = 100
population_std = 10
sample = np.array([102, 98, 101, 99, 100])
n = len(sample)

# Step 2: Calculate sample mean
sample_mean = np.mean(sample)

# Step 3: Calculate Z-statistic
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))

# Step 4: Critical Z-value for α = 0.05 (two-tailed)
z_critical = norm.ppf(1 - 0.05 / 2)  # ≈ 1.96

# Step 5: Print result
print(f"Sample Mean: {sample_mean}")
print(f"Z-statistic: {z:.2f}")
print(f"Critical Z-value: ±{z_critical:.2f}")

if abs(z) > z_critical:
    print("✅ Reject the null hypothesis (significant difference).")
else:
    print("❌ Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean: 100.0
# Z-statistic: 0.00
# Critical Z-value: ±1.96
# ❌ Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# 20.Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy import stats

# Step 1: Sample data
data = np.array([78, 82, 85, 90, 87, 76, 80, 79, 83, 88])
n = len(data)
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # sample standard deviation

# Step 2: Confidence level and t-critical value
confidence = 0.95
alpha = 1 - confidence
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)

# Step 3: Margin of error and confidence interval
margin_of_error = t_critical * (sample_std / np.sqrt(n))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Step 4: Print result
print(f"Sample Mean = {sample_mean:.2f}")
print(f"95% Confidence Interval = ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Sample Mean = 82.80
# 95% Confidence Interval = (79.48, 86.12)

# %% [markdown]
# 21.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy import stats

# Step 1: Generate small normal dataset
np.random.seed(1)
data = np.random.normal(loc=50, scale=5, size=10)  # mean=50, std=5, n=10

# Step 2: Calculate sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
n = len(data)

# Step 3: Calculate 95% confidence interval
confidence = 0.95
t_critical = stats.t.ppf(1 - 0.05/2, df=n-1)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

lower = sample_mean - margin_of_error
upper = sample_mean + margin_of_error

# Step 4: Print result
print(f"Sample Mean = {sample_mean:.2f}")
print(f"95% Confidence Interval = ({lower:.2f}, {upper:.2f})")
# Out:
# Sample Mean = 49.51
# 95% Confidence Interval = (45.02, 54.00)

# %% [markdown]
# 22.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Define parameters for the normal distribution
mean = 0       # mean of the distribution
std_dev = 1    # standard deviation

# Step 2: Generate x values (domain)
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Step 3: Calculate PDF values
pdf = norm.pdf(x, mean, std_dev)

# Step 4: Plot the PDF
plt.plot(x, pdf, color='blue', label='Normal PDF')
plt.title("Normal Distribution (μ = 0, σ = 1)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 23.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
from scipy.stats import poisson

# Step 1: Set Poisson distribution parameter
mu = 3  # average rate (λ)

# Step 2: Choose value of k (number of events)
k = 3

# Step 3: Calculate CDF
cdf_value = poisson.cdf(k, mu)

# Step 4: Print result
print(f"P(X ≤ {k}) for λ = {mu} is {cdf_value:.4f}")
# Out:
# P(X ≤ 3) for λ = 3 is 0.6472

# %% [markdown]
# 24.Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np

# Step 1: Define the interval [a, b]
a = 10
b = 20

# Step 2: Simulate random values from the uniform distribution
np.random.seed(0)  # for reproducibility
samples = np.random.uniform(a, b, size=1000)

# Step 3: Calculate expected value (sample mean)
sample_mean = np.mean(samples)

# Step 4: Theoretical expected value
theoretical_mean = (a + b) / 2

# Step 5: Print results
print(f"Sample Mean (Simulated Expected Value): {sample_mean:.2f}")
print(f"Theoretical Expected Value: {theoretical_mean:.2f}")
# Out:
# Sample Mean (Simulated Expected Value): 14.96
# Theoretical Expected Value: 15.00

# %% [markdown]
# 25.Write a Python program to compare the standard deviations of two datasets and visualize the difference

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create two datasets
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=100)   # small spread
data2 = np.random.normal(loc=50, scale=15, size=100)  # large spread

# Step 2: Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

# Step 3: Print the standard deviations
print(f"Standard Deviation of Data1: {std1:.2f}")
print(f"Standard Deviation of Data2: {std2:.2f}")

# Step 4: Visualize the datasets
plt.hist(data1, bins=15, alpha=0.7, label=f'Data1 (std = {std1:.2f})', color='blue')
plt.hist(data2, bins=15, alpha=0.7, label=f'Data2 (std = {std2:.2f})', color='orange')
plt.title("Comparison of Standard Deviations")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Data1: 4.54
# Standard Deviation of Data2: 14.31

# %% [markdown]
# 27.Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np

# Step 1: Small dataset
data = np.array([10, 20, 30, 40, 50])

# Step 2: Calculate mean and standard deviation
mean = np.mean(data)
std = np.std(data)

# Step 3: Z-score normalization
z_scores = (data - mean) / std

# Step 4: Print results
print("Original Data: ", data)
print("Z-score Normalized Data: ", np.round(z_scores, 2))
# Out:
# Original Data:  [10 20 30 40 50]
# Z-score Normalized Data:  [-1.41 -0.71  0.    0.71  1.41]

# %% [markdown]
# 28.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
# distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(size=1000, mean=0, std_dev=1):
    # Step 1: Generate normal distribution data
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    # Step 2: Calculate skewness and kurtosis
    data_skewness = skew(data)
    data_kurtosis = kurtosis(data)  # excess kurtosis (normal = 0)

    # Step 3: Print the results
    print(f"Skewness: {data_skewness:.4f}")
    print(f"Kurtosis (Excess): {data_kurtosis:.4f}")

# Example usage
calculate_skewness_kurtosis()
# Out:
# Skewness: 0.0369
# Kurtosis (Excess): 0.0301
